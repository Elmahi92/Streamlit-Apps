# %%
import pandas as pd
import requests

# %%
base_url = 'https://api.acleddata.com/'
country = "Sudan"
email = "mohamed.omer@undp.org"
api_key = "eU*u2SEKePnQiv9d!qXI"

# %%
all_data = []  # To store data from all API requests
limit = 2000  # Number of records per request
offset = 0  # Used to paginate
base_url = f"https://api.acleddata.com/acled/read?key={api_key}&email={email}"

# Params for the API request
params = {
    'country': country,
    'limit': limit,
    'offset': offset
}

# %%
response=requests.get(base_url, params=params)
response_json=response.json()

# %%
data=response_json['data']
all_data.extend(data)
pd.DataFrame(all_data)
# Out:
#      event_id_cnty  event_date  year time_precision           disorder_type  \
# 0         SUD30016  2024-09-13  2024              2      Political violence
# 1         SUD30017  2024-09-13  2024              2      Political violence
# 2         SUD30018  2024-09-13  2024              1      Political violence
# 3         SUD30019  2024-09-13  2024              1      Political violence
# 4         SUD30020  2024-09-13  2024              1      Political violence
# ...            ...         ...   ...            ...                     ...
# 5995      SUD27870  2024-05-12  2024              1      Political violence
# 5996      SUD27872  2024-05-12  2024              1  Strategic developments
# 5997      SUD27854  2024-05-12  2024              1      Political violence
# 5998      SUD27861  2024-05-12  2024              2  Strategic developments
# 5999      SUD27851  2024-05-12  2024              2  Strategic developments
#
#                       event_type                     sub_event_type  \
# 0     Violence against civilians                             Attack
# 1     Explosions/Remote violence                    Chemical weapon
# 2     Explosions/Remote violence                   Air/drone strike
# 3     Explosions/Remote violence                   Air/drone strike
# 4     Explosions/Remote violence                   Air/drone strike
# ...                          ...                                ...
# 5995  Violence against civilians                             Attack
# 5996      Strategic developments                              Other
# 5997  Explosions/Remote violence  Shelling/artillery/missile attack
# 5998      Strategic developments                              Other
# 5999      Strategic developments                              Other
#
#                                 actor1 assoc_actor_1 inter1  ...  \
# 0                 Rapid Support Forces                    2  ...
# 1     Military Forces of Sudan (2019-)                    1  ...
# 2     Military Forces of Sudan (2019-)                    1  ...
# 3     Military Forces of Sudan (2019-)                    1  ...
# 4     Military Forces of Sudan (2019-)                    1  ...
# ...                                ...           ...    ...  ...
# 5995              Rapid Support Forces                    2  ...
# 5996  Military Forces of Sudan (2019-)                    1  ...
# 5997  Unidentified Armed Group (Sudan)                    3  ...
# 5998              Rapid Support Forces                    2  ...
# 5999              Rapid Support Forces                    2  ...
#
#                               location latitude longitude geo_precision  \
# 0              Wad Al Daw Al Arakiyyin  14.3243   33.3707             1
# 1                             Al Gaili  16.0113   32.5862             1
# 2     Khartoum North - Industrial Area  15.6518   32.5553             1
# 3             Khartoum North - Shambat  15.6594   32.5300             1
# 4                  Khartoum - Arkaweet  15.5504   32.5662             2
# ...                                ...      ...       ...           ...
# 5995                        Al Ghabsha  12.9293   31.4801             2
# 5996                            Merowe  18.4657   31.8146             2
# 5997              Khartoum - Alsalamah  15.4856   32.5791             1
# 5998               Omdurman - Abu Seid  15.6045   32.4370             1
# 5999                         Al Safyia  15.6507   32.5365             1
#
#                                                source        source_scale  \
# 0                                          Al Jazeera            Regional
# 1                                           Erem News       International
# 2     Al Jazeera; Al Mashhad Al Sudani; Sudan Tribune   National-Regional
# 3                                       Sudan Tribune            National
# 4                                       Sudan Tribune            National
# ...                                               ...                 ...
# 5995                                     IOM; Twitter     Other-New media
# 5996                    Al Mashhad Al Sudani; Twitter  New media-National
# 5997            Radio Dabanga; Radio Tamazuj; Twitter  New media-National
# 5998         Al Mashhad Al Sudani; Al Sudani; Twitter  New media-National
# 5999                                    Sudan Tribune            National
#
#                                                   notes fatalities tags  \
# 0     Around 13 September 2024 (as reported), RSF sh...          0
# 1     Around 13 September 2024 (as reported), SAF ai...          0
# 2     On 13 September 2024, SAF airstrikes targeted ...          3
# 3     On 13 September 2024, SAF airstrikes targeted ...          0
# 4     On 13 September 2024, SAF airstrikes targeted ...          0
# ...                                                 ...        ...  ...
# 5995  On 12 May 2024, RSF attacked civilians in Shei...          3
# 5996  Other: On 12 May 2024, SAF 19 Infantry Divisio...          0
# 5997  On 12 May 2024, an armed group (unclear if SAF...          6
# 5998  Non-violent activity: Around 12 May 2024 (as r...          0
# 5999  Other: Around 12 May 2024 (as reported), RSF c...          0
#
#        timestamp
# 0     1726526151
# 1     1726526151
# 2     1726526151
# 3     1726526151
# 4     1726526151
# ...          ...
# 5995  1716328040
# 5996  1716850558
# 5997  1719876544
# 5998  1719876544
# 5999  1722291579
#
# [6000 rows x 31 columns]

# %%
from datetime import datetime
import configparser
config = configparser.ConfigParser()
config.read('config.txt')
email = config['API']['email']
api_key = config['API']['api_key']
country = config['API']['country']
start_date = config['API']['start_date']
end_date = datetime.now().strftime('%Y-%m-%d')
event_date = f"{start_date}|{end_date}"

all_data = []  # To store data from all API requests
limit = 20000  # Number of records per request
offset = 0  # Used to paginate
base_url = f"https://api.acleddata.com/acled/read"
# Params for the API request

# Define the parameters
params = {
    'key': api_key,
    'email': email,
    'country': country,
    'event_date': event_date,  # Use pipe separator in event_date
    'event_date_where': 'BETWEEN',
    'limit': limit,
    'offset': offset
}

response=requests.get(base_url, params=params)
response_json=response.json()
data=response_json['data']
all_data.extend(data)
pd.DataFrame(all_data)
# Out:
#       event_id_cnty  event_date  year time_precision       disorder_type  \
# 0          SUD30016  2024-09-13  2024              2  Political violence
# 1          SUD30017  2024-09-13  2024              2  Political violence
# 2          SUD30018  2024-09-13  2024              1  Political violence
# 3          SUD30019  2024-09-13  2024              1  Political violence
# 4          SUD30020  2024-09-13  2024              1  Political violence
# ...             ...         ...   ...            ...                 ...
# 10716      SUD18708  2023-01-02  2023              1  Political violence
# 10717      SUD18742  2023-01-02  2023              1      Demonstrations
# 10718      SUD18712  2023-01-01  2023              1  Political violence
# 10719      SUD18717  2023-01-01  2023              1  Political violence
# 10720      SUD18761  2023-01-01  2023              1  Political violence
#
#                        event_type             sub_event_type  \
# 0      Violence against civilians                     Attack
# 1      Explosions/Remote violence            Chemical weapon
# 2      Explosions/Remote violence           Air/drone strike
# 3      Explosions/Remote violence           Air/drone strike
# 4      Explosions/Remote violence           Air/drone strike
# ...                           ...                        ...
# 10716  Violence against civilians                     Attack
# 10717                    Protests  Protest with intervention
# 10718                       Riots               Mob violence
# 10719  Violence against civilians            Sexual violence
# 10720  Violence against civilians                     Attack
#
#                                  actor1  \
# 0                  Rapid Support Forces
# 1      Military Forces of Sudan (2019-)
# 2      Military Forces of Sudan (2019-)
# 3      Military Forces of Sudan (2019-)
# 4      Military Forces of Sudan (2019-)
# ...                                 ...
# 10716   Twic Clan Militia (South Sudan)
# 10717                Protesters (Sudan)
# 10718                   Rioters (Sudan)
# 10719   Darfur Communal Militia (Sudan)
# 10720   Darfur Communal Militia (Sudan)
#
#                                            assoc_actor_1 inter1  ...  \
# 0                                                             2  ...
# 1                                                             1  ...
# 2                                                             1  ...
# 3                                                             1  ...
# 4                                                             1  ...
# ...                                                  ...    ...  ...
# 10716  Bul Clan Militia (South Sudan); Dinka Ethnic M...      4  ...
# 10717                      Resistance Committees (Sudan)      6  ...
# 10718                                   Students (Sudan)      5  ...
# 10719                                                         4  ...
# 10720                                                         4  ...
#
#                                location latitude longitude geo_precision  \
# 0               Wad Al Daw Al Arakiyyin  14.3243   33.3707             1
# 1                              Al Gaili  16.0113   32.5862             1
# 2      Khartoum North - Industrial Area  15.6518   32.5553             1
# 3              Khartoum North - Shambat  15.6594   32.5300             1
# 4                   Khartoum - Arkaweet  15.5504   32.5662             2
# ...                                 ...      ...       ...           ...
# 10716                          Rumamier   9.4422   28.6622             1
# 10717                  Khartoum - Burri  15.6046   32.5781             1
# 10718                           Dilling  12.0509   29.6542             1
# 10719                           Sortine  13.4004   24.3098             2
# 10720                           Sortine  13.4004   24.3098             2
#
#                                                 source  \
# 0                                           Al Jazeera
# 1                                            Erem News
# 2      Al Jazeera; Al Mashhad Al Sudani; Sudan Tribune
# 3                                        Sudan Tribune
# 4                                        Sudan Tribune
# ...                                                ...
# 10716          Radio Tamazuj; Sudans Post; UNOCHA; VOA
# 10717                                          Twitter
# 10718                        Alintibaha; Radio Dabanga
# 10719                                    Radio Dabanga
# 10720                                    Radio Dabanga
#
#                  source_scale  \
# 0                    Regional
# 1               International
# 2           National-Regional
# 3                    National
# 4                    National
# ...                       ...
# 10716  Regional-International
# 10717               New media
# 10718                National
# 10719                National
# 10720                National
#
#                                                    notes fatalities  \
# 0      Around 13 September 2024 (as reported), RSF sh...          0
# 1      Around 13 September 2024 (as reported), SAF ai...          0
# 2      On 13 September 2024, SAF airstrikes targeted ...          3
# 3      On 13 September 2024, SAF airstrikes targeted ...          0
# 4      On 13 September 2024, SAF airstrikes targeted ...          0
# ...                                                  ...        ...
# 10716  On 2 January 2023, around 200 armed Twic Dinka...         13
# 10717  On 2 January 2023, Resistance Committees stage...          0
# 10718  On 1 January 2023, two student groups fight ea...          0
# 10719  On 1 January 2023, militiamen (coded as Darfur...          0
# 10720  On 1 January 2023, militiamen (coded as Darfur...          0
#
#                         tags   timestamp
# 0                             1726526151
# 1                             1726526151
# 2                             1726526151
# 3                             1726526151
# 4                             1726526151
# ...                      ...         ...
# 10716                         1724787177
# 10717   crowd size=no report  1726526149
# 10718   crowd size=no report  1673291089
# 10719  women targeted: girls  1673291089
# 10720                         1673291089
#
# [10721 rows x 31 columns]

# %%
import configparser
import requests
import pandas as pd
from datetime import datetime

def fetch_acled_data():
    # Read the configuration file
    config = configparser.ConfigParser()
    config.read('config.txt')
    
    # Extract necessary parameters from config
    email = config['API']['email']
    api_key = config['API']['api_key']
    country = config['API']['country']
    start_date = config['API']['start_date']
    
    # Get the current date in 'yyyy-mm-dd' format for the end_date
    end_date = datetime.now().strftime('%Y-%m-%d')
    
    # Create the event_date string using the pipe separator
    event_date = f"{start_date}|{end_date}"
    
    all_data = []  # To store data from all API requests
    limit = 20000  # Number of records per request
    offset = 0  # Used to paginate
    base_url = "https://api.acleddata.com/acled/read"
    
    # Define the parameters
    params = {
        'key': api_key,
        'email': email,
        'country': country,
        'event_date': event_date,  # Use pipe separator in event_date
        'event_date_where': 'BETWEEN',
        'limit': limit,
        'offset': offset
    }

    # Send the GET request
    response = requests.get(base_url, params=params)
    
    # Raise exception if the request fails
    response.raise_for_status()
    
    # Parse the response JSON
    response_json = response.json()
    data = response_json['data']
    
    # Extend all_data with the fetched data
    all_data.extend(data)
    
    # Return the data as a DataFrame
    return pd.DataFrame(all_data)

# Example of calling the function
df = fetch_acled_data()
print(df)
# Out:
#       event_id_cnty  event_date  year time_precision       disorder_type  \
# 0          SUD30016  2024-09-13  2024              2  Political violence
# 1          SUD30017  2024-09-13  2024              2  Political violence
# 2          SUD30018  2024-09-13  2024              1  Political violence
# 3          SUD30019  2024-09-13  2024              1  Political violence
# 4          SUD30020  2024-09-13  2024              1  Political violence
# ...             ...         ...   ...            ...                 ...
# 10121      SUD19583  2023-04-02  2023              1      Demonstrations
# 10122      SUD19510  2023-04-01  2023              1  Political violence
# 10123      SUD19525  2023-04-01  2023              1      Demonstrations
# 10124      SUD19566  2023-04-01  2023              1      Demonstrations
# 10125      SUD19573  2023-04-01  2023              1      Demonstrations
#
#                        event_type         sub_event_type  \
# 0      Violence against civilians                 Attack
# 1      Explosions/Remote violence        Chemical weapon
# 2      Explosions/Remote violence       Air/drone strike
# 3      Explosions/Remote violence       Air/drone strike
# 4      Explosions/Remote violence       Air/drone strike
# ...                           ...                    ...
# 10121                    Protests       Peaceful protest
# 10122  Violence against civilians                 Attack
# 10123                       Riots  Violent demonstration
# 10124                       Riots  Violent demonstration
# 10125                       Riots  Violent demonstration
#
#                                  actor1  \
# 0                  Rapid Support Forces
# 1      Military Forces of Sudan (2019-)
# 2      Military Forces of Sudan (2019-)
# 3      Military Forces of Sudan (2019-)
# 4      Military Forces of Sudan (2019-)
# ...                                 ...
# 10121                Protesters (Sudan)
# 10122   Darfur Communal Militia (Sudan)
# 10123                   Rioters (Sudan)
# 10124                   Rioters (Sudan)
# 10125                   Rioters (Sudan)
#
#                                         assoc_actor_1 inter1  ...  \
# 0                                                          2  ...
# 1                                                          1  ...
# 2                                                          1  ...
# 3                                                          1  ...
# 4                                                          1  ...
# ...                                               ...    ...  ...
# 10121                   Resistance Committees (Sudan)      6  ...
# 10122                                                      4  ...
# 10123  BC: Beja Congress; Beja Ethnic Militia (Sudan)      5  ...
# 10124  BC: Beja Congress; Beja Ethnic Militia (Sudan)      5  ...
# 10125  BC: Beja Congress; Beja Ethnic Militia (Sudan)      5  ...
#
#                                location latitude longitude geo_precision  \
# 0               Wad Al Daw Al Arakiyyin  14.3243   33.3707             1
# 1                              Al Gaili  16.0113   32.5862             1
# 2      Khartoum North - Industrial Area  15.6518   32.5553             1
# 3              Khartoum North - Shambat  15.6594   32.5300             1
# 4                   Khartoum - Arkaweet  15.5504   32.5662             2
# ...                                 ...      ...       ...           ...
# 10121                        Wad Medani  14.3983   33.5477             1
# 10122                        Saraf Omra  13.4771   23.3117             2
# 10123                        Port Sudan  19.6148   37.2225             2
# 10124                             Aroma  15.8109   36.1367             2
# 10125                           Kassala  15.4296   36.4105             2
#
#                                                   source        source_scale  \
# 0                                             Al Jazeera            Regional
# 1                                              Erem News       International
# 2        Al Jazeera; Al Mashhad Al Sudani; Sudan Tribune   National-Regional
# 3                                          Sudan Tribune            National
# 4                                          Sudan Tribune            National
# ...                                                  ...                 ...
# 10121                                        Hala haya 5           New media
# 10122                          Alintibaha; Radio Dabanga            National
# 10123  Al Taghyeer (Sudan); Alhamish Voice; Alintibah...  New media-National
# 10124  Al Taghyeer (Sudan); Alhamish Voice; Alintibah...            National
# 10125                          Alintibaha; Radio Dabanga            National
#
#                                                    notes fatalities  \
# 0      Around 13 September 2024 (as reported), RSF sh...          0
# 1      Around 13 September 2024 (as reported), SAF ai...          0
# 2      On 13 September 2024, SAF airstrikes targeted ...          3
# 3      On 13 September 2024, SAF airstrikes targeted ...          0
# 4      On 13 September 2024, SAF airstrikes targeted ...          0
# ...                                                  ...        ...
# 10121  On 2 April 2023, demonstrators responded to ca...          0
# 10122  On 1 April 2023, seven militants on three moto...          0
# 10123  On 1 April 2023, dozens of Beja Congress membe...          0
# 10124  On 1 April 2023, dozens of Beja Congress membe...          0
# 10125  On 1 April 2023, dozens of Beja Congress membe...          0
#
#                        tags   timestamp
# 0                            1726526151
# 1                            1726526151
# 2                            1726526151
# 3                            1726526151
# 4                            1726526151
# ...                     ...         ...
# 10121  crowd size=no report  1722291575
# 10122                        1681225751
# 10123     crowd size=dozens  1681225751
# 10124     crowd size=dozens  1681225751
# 10125     crowd size=dozens  1711409525
#
# [10126 rows x 31 columns]
